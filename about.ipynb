# %% [raw]
# ---
# title: "Brenda Cruz"
# subtitle: Bioinformatics
# about:
#   template: trestles
#   image: images/yas.jpeg
#   image-width: 15em
#   id: hero-heading
#   links:
#     - icon: linkedin
#       href: www.linkedin.com/in/brenda-cruz-0792b0234
#     - icon: github
#       href: https://github.com/bscruz
# include header-includes:
#   - <script src="./assets/oneko.js"></script>
# extension-resources: assets/oneko.js
# format:
#   html:
#     header-incudes:
#       -text:
#         - <script type="text/javascript" src="./assets/oneko.js"></script>
#     page-layout: full
# ---

# %% [markdown]
# ------------------------------------------------------------------------
#
#
# ::: {#hero-heading}
# ::: h1
# Hey, I'm happy you're here
# :::
#
# I'm currently a part of the LIFT Bioinnovation group working on setting up a computaional data course for UC Davis
#
# ------------------------------------------------------------------------
#
# ::: h1
# Education
# :::
#
# University of California, Davis
#
# B.S in Biotechnology with a Specialization in Bioinformatics \| Sept 2021 - June 2025 \|
#
# Contra Costa College \| Sept 2019 - June 2021 \|
# :::
#
# ::: h1
# Experience
# :::
#
# ::: grid
# ::: {#about-me-1 .g-col-6}
# ```
# UC Davis Analytical Laboratory January 2023 -- June 2024|Assistant Davis, CA
# ```
#
# -   Assist laboratory technicians with 40+ soil measurements daily and performances of analysis on selected chemical constituents of soil, plant, water, and feed
# :::
#
# ::: {#about-me-2 .g-col-6}
# ```
# Data Intensive Biology Lab June 2023 -- June 2024|Intern Davis, CA
# ```
#
# -   Formulating experimental approaches to current questions in biotechnology; performance of proposed experiments.
#
# -   Duties include quality analysis and control for sequencing data, assembling and annotating metagenomic reads, quickly comparing large sequencing datasets, document workflows using git and GitHub.
#
# ###
# :::
# :::
#
#
#
# <!-- end grid -->
#
# ```{=html}
# <script src="assets/oneko.js"></script>
# ```
#
# ```{js}
# document.addEventListener("DOMContentLoaded", function() {
#     function oneko() {
#         const nekoEl = document.createElement("div");
#         let nekoPosX = 32;
#         let nekoPosY = 32;
#         let mousePosX = 0;
#         let mousePosY = 0;
#         let frameCount = 0;
#         let idleTime = 0;
#         let idleAnimation = null;
#         let idleAnimationFrame = 0;
#         const nekoSpeed = 10;
#
#         const spriteSets = {
#             idle: [[-3, -3]],
#             alert: [[-7, -3]],
#             scratch: [
#                 [-5, 0],
#                 [-6, 0],
#                 [-7, 0],
#             ],
#             tired: [[-3, -2]],
#             sleeping: [
#                 [-2, 0],
#                 [-2, -1],
#             ],
#             N: [
#                 [-1, -2],
#                 [-1, -3],
#             ],
#             NE: [
#                 [0, -2],
#                 [0, -3],
#             ],
#             E: [
#                 [-3, 0],
#                 [-3, -1],
#             ],
#             SE: [
#                 [-5, -1],
#                 [-5, -2],
#             ],
#             S: [
#                 [-6, -3],
#                 [-7, -2],
#             ],
#             SW: [
#                 [-5, -3],
#                 [-6, -1],
#             ],
#             W: [
#                 [-4, -2],
#                 [-4, -3],
#             ],
#             NW: [
#                 [-1, 0],
#                 [-1, -1],
#             ],
#         };
#
#         // Create the cat element
#         function create() {
#             nekoEl.id = "oneko";
#             nekoEl.style.width = "32px";
#             nekoEl.style.height = "32px";
#             nekoEl.style.position = "fixed";
#             nekoEl.style.backgroundImage = "('img/oneko.image')";
#             nekoEl.style.imageRendering = "pixelated";
#             nekoEl.style.left = "16px";
#             nekoEl.style.top = "16px";
#             nekoEl.style.zIndex = "99999";
#
#             document.body.appendChild(nekoEl);
#
#             // Track mouse position
#             document.onmousemove = (event) => {
#                 mousePosX = event.clientX;
#                 mousePosY = event.clientY;
#             };
#
#             window.onekoInterval = setInterval(frame, 100);
#         }
#
#         // Set the sprite for the neko based on the current animation frame
#         function setSprite(name, frame) {
#             const sprite = spriteSets[name][frame % spriteSets[name].length];
#             nekoEl.style.backgroundPosition = `${sprite[0] * 32}px ${sprite[1] * 32}px`;
#         }
#
#         // Reset idle animation
#         function resetIdleAnimation() {
#             idleAnimation = null;
#             idleAnimationFrame = 0;
#         }
#
#         // Handle idle animations (sleeping, scratching, etc.)
#         function idle() {
#             idleTime += 1;
#
#             // Every ~ 20 seconds, start a random idle animation
#             if (
#                 idleTime > 10 &&
#                 Math.floor(Math.random() * 200) == 0 &&
#                 idleAnimation == null
#             ) {
#                 idleAnimation = ["sleeping", "scratch"][
#                     Math.floor(Math.random() * 2)
#                 ];
#             }
#
#             switch (idleAnimation) {
#                 case "sleeping":
#                     if (idleAnimationFrame < 8) {
#                         setSprite("tired", 0);
#                         break;
#                     }
#                     setSprite("sleeping", Math.floor(idleAnimationFrame / 4));
#                     if (idleAnimationFrame > 192) {
#                         resetIdleAnimation();
#                     }
#                     break;
#                 case "scratch":
#                     setSprite("scratch", idleAnimationFrame);
#                     if (idleAnimationFrame > 9) {
#                         resetIdleAnimation();
#                     }
#                     break;
#                 default:
#                     setSprite("idle", 0);
#                     return;
#             }
#             idleAnimationFrame += 1;
#         }
#
#         // Main animation loop to follow mouse and update position
#         function frame() {
#             frameCount += 1;
#             const diffX = nekoPosX - mousePosX;
#             const diffY = nekoPosY - mousePosY;
#             const distance = Math.sqrt(diffX ** 2 + diffY ** 2);
#
#             if (distance < nekoSpeed || distance < 48) {
#                 idle();
#                 return;
#             }
#
#             idleAnimation = null;
#             idleAnimationFrame = 0;
#
#             if (idleTime > 1) {
#                 setSprite("alert", 0);
#                 idleTime = Math.min(idleTime, 7);
#                 idleTime -= 1;
#                 return;
#             }
#
#             let direction = "";
#             direction = diffY / distance > 0.5 ? "N" : "";
#             direction += diffY / distance < -0.5 ? "S" : "";
#             direction += diffX / distance > 0.5 ? "W" : "";
#             direction += diffX / distance < -0.5 ? "E" : "";
#
#             setSprite(direction, frameCount);
#
#             nekoPosX -= (diffX / distance) * nekoSpeed;
#             nekoPosY -= (diffY / distance) * nekoSpeed;
#
#             nekoEl.style.left = `${nekoPosX - 16}px`;
#             nekoEl.style.top = `${nekoPosY - 16}px`;
#         }
#
#         // Initialize the cat element when the DOM is ready
#         create();
#     }
#
#     // Run the oneko function when the DOM is fully loaded
#     oneko();
# });
